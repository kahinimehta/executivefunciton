# %%
#This script uploads BIDS-valid task data (.tsv's and .json's) to corresponding sessions in a flywheel project. 
#Inputs:
    #directory of converted task data (from PennBox)
#Outputs: 
    #none

# %%
import glob
import flywheel
fw = flywheel.Client()

# %%
#set project using name on flywheel 
EFProj=fw.projects.find_first('label=EFR01')
print(EFProj)
# Out:
# WARNING:Flywheel:Use "pip install flywheel-sdk~=16.4.4" to install a compatible version for this server
# {'analyses': [],
#  'created': datetime.datetime(2019, 3, 22, 12, 36, 22, 89000, tzinfo=tzutc()),
#  'description': '',
#  'editions': {'lab': True},
#  'files': [{'classification': {},
#             'created': datetime.datetime(2020, 8, 13, 18, 4, 51, 832000, tzinfo=tzutc()),
#             'deid_log_id': None,
#             'file_id': '622fbd1cfa62e8ba6cd21573',
#             'hash': 'v0-sha384-d32346fbbcef94610c9d4fb7f0209743753b988ed5225da600f7bd9e52440653522cce4d3c5d2989327caea0ed249c01',
#             'id': '65e23a9a-9700-42d1-8885-963282d7faf9',
#             'info': {},
#             'info_exists': False,
#             'mimetype': 'text/x-python',
#             'modality': None,
#             'modified': datetime.datetime(2020, 8, 13, 18, 4, 51, 408000, tzinfo=tzutc()),
#             'name': 'EF_heuristic.py',
#             'origin': {'id': 'krmurtha@upenn.edu',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'parent_ref': {'id': '5c94d6c6f546b6002dbe3a81', 'type': 'project'},
#             'parents': {'acquisition': None,
#                         'analysis': None,
#                         'group': 'bbl',
#                         'project': '5c94d6c6f546b6002dbe3a81',
#                         'session': None,
#                         'subject': None},
#             'replaced': None,
#             'size': 7241,
#             'tags': [],
#             'type': 'source code',
#             'version': 1,
#             'zip_member_count': None},
#            {'classification': {},
#             'created': datetime.datetime(2020, 12, 23, 15, 9, 21, 355000, tzinfo=tzutc()),
#             'deid_log_id': None,
#             'file_id': '622fbd1cfa62e8ba6cd21575',
#             'hash': 'v0-sha384-3e4049782a18870249141ce0b3a212b9f62a9fd28b8bc18b4e31e844d278e4cadd7065f6954f3ce557013e9220a370a6',
#             'id': '526cef8b-e7fe-4d6c-bb80-8d18a8e625e9',
#             'info': {},
#             'info_exists': False,
#             'mimetype': 'application/octet-stream',
#             'modality': None,
#             'modified': datetime.datetime(2020, 12, 23, 15, 9, 20, 771000, tzinfo=tzutc()),
#             'name': 'deid_profile.yaml',
#             'origin': {'id': 'jeffyager@flywheel.io',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'parent_ref': {'id': '5c94d6c6f546b6002dbe3a81', 'type': 'project'},
#             'parents': {'acquisition': None,
#                         'analysis': None,
#                         'group': 'bbl',
#                         'project': '5c94d6c6f546b6002dbe3a81',
#                         'session': None,
#                         'subject': None},
#             'replaced': None,
#             'size': 4488,
#             'tags': [],
#             'type': 'source code',
#             'version': 1,
#             'zip_member_count': None},
#            {'classification': {'Custom': []},
#             'created': datetime.datetime(2019, 6, 4, 15, 27, 34, 936000, tzinfo=tzutc()),
#             'deid_log_id': None,
#             'file_id': '622fbd1cfa62e8ba6cd21571',
#             'hash': 'v0-sha384-b9dd45b02f17578af93c13a9b05bf0e7dd3e21318d1404b26fa9cada0edb1fdfb4758a8829c23513589b9cef8d187514',
#             'id': 'abe4a4a9-0cfa-41a1-b026-2be60fc1a9d2',
#             'info': {},
#             'info_exists': False,
#             'mimetype': 'text/x-python',
#             'modality': None,
#             'modified': datetime.datetime(2021, 9, 27, 19, 40, 33, 287000, tzinfo=tzutc()),
#             'name': 'efr01_heuristic.py',
#             'origin': {'id': 'annaxu@upenn.edu',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'parent_ref': {'id': '5c94d6c6f546b6002dbe3a81', 'type': 'project'},
#             'parents': {'acquisition': None,
#                         'analysis': None,
#                         'group': 'bbl',
#                         'project': '5c94d6c6f546b6002dbe3a81',
#                         'session': None,
#                         'subject': None},
#             'replaced': None,
#             'size': 3146,
#             'tags': [],
#             'type': 'source code',
#             'version': 1,
#             'zip_member_count': None},
#            {'classification': {'Custom': []},
#             'created': datetime.datetime(2019, 6, 4, 17, 39, 13, 364000, tzinfo=tzutc()),
#             'deid_log_id': None,
#             'file_id': '622fbd1cfa62e8ba6cd21572',
#             'hash': 'v0-sha384-b81f49fc302dc4acc73682a843f6d3c02399dc2c4c69d449b81a5b5c705018274e499a198a3ff5b8178cb7e2e5758ce8',
#             'id': 'd76e9fa2-1507-4cd5-82d1-2124e020f61d',
#             'info': {},
#             'info_exists': False,
#             'mimetype': 'text/x-python',
#             'modality': None,
#             'modified': datetime.datetime(2021, 9, 27, 19, 40, 44, 197000, tzinfo=tzutc()),
#             'name': 'efr01_heuristic_20190604.py',
#             'origin': {'id': 'annaxu@upenn.edu',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'parent_ref': {'id': '5c94d6c6f546b6002dbe3a81', 'type': 'project'},
#             'parents': {'acquisition': None,
#                         'analysis': None,
#                         'group': 'bbl',
#                         'project': '5c94d6c6f546b6002dbe3a81',
#                         'session': None,
#                         'subject': None},
#             'replaced': None,
#             'size': 3292,
#             'tags': [],
#             'type': 'source code',
#             'version': 1,
#             'zip_member_count': None},
#            {'classification': {},
#             'created': datetime.datetime(2020, 10, 2, 17, 37, 29, 357000, tzinfo=tzutc()),
#             'deid_log_id': None,
#             'file_id': '622fbd1cfa62e8ba6cd21574',
#             'hash': 'v0-sha384-ac4374121e8656ddbdeb95debd4ab4279211b6b28723af21e8b21cef6e0ff0b74c6f6a458a6b495561bbdddbd74f7d6e',
#             'id': 'f9a89f32-d3e8-4908-9045-960f51eeed90',
#             'info': {},
#             'info_exists': False,
#             'mimetype': 'text/plain',
#             'modality': None,
#             'modified': datetime.datetime(2020, 10, 2, 17, 37, 28, 897000, tzinfo=tzutc()),
#             'name': 'license.txt',
#             'origin': {'id': 'krmurtha@upenn.edu',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'parent_ref': {'id': '5c94d6c6f546b6002dbe3a81', 'type': 'project'},
#             'parents': {'acquisition': None,
#                         'analysis': None,
#                         'group': 'bbl',
#                         'project': '5c94d6c6f546b6002dbe3a81',
#                         'session': None,
#                         'subject': None},
#             'replaced': None,
#             'size': 55,
#             'tags': [],
#             'type': 'text',
#             'version': 1,
#             'zip_member_count': None}],
#  'group': 'bbl',
#  'id': '5c94d6c6f546b6002dbe3a81',
#  'info': {'BIDS': {'Acknowledgements': '',
#                    'Authors': [],
#                    'BIDSVersion': '1.0.2',
#                    'DatasetDOI': '',
#                    'Funding': [],
#                    'HowToAcknowledge': '',
#                    'License': '',
#                    'Name': 'EFR01',
#                    'ReferencesAndLinks': [],
#                    'template': 'project'}},
#  'info_exists': True,
#  'label': 'EFR01',
#  'ldap_sync': None,
#  'modified': datetime.datetime(2022, 3, 8, 23, 3, 1, 577000, tzinfo=tzutc()),
#  'notes': [],
#  'parents': {'acquisition': None,
#              'analysis': None,
#              'group': 'bbl',
#              'project': None,
#              'session': None,
#              'subject': None},
#  'permissions': [{'access': None,
#                   'id': 'holder@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa3']},
#                  {'access': None,
#                   'id': 'adebimpe@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa3']},
#                  {'access': None,
#                   'id': 'mcieslak@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa3']},
#                  {'access': None,
#                   'id': 'melliott@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa3']},
#                  {'access': None,
#                   'id': 'harshakethineni@flywheel.io',
#                   'role_ids': ['5ef07972374bc20010a37aa3']},
#                  {'access': None,
#                   'id': 'sattertt@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa3']},
#                  {'access': None,
#                   'id': 'kruparel@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa3']},
#                  {'access': None,
#                   'id': 'arikahn@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'roalf@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'danwolf@pennmedicine.upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'danwolf@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'gpretty@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'tessglev@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'gur@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'tymoore@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'adrose@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'raquel@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'jschmitt@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'rsga@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'sagerush@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'zaixucui@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'diegodav@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'hxia@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'kpiiwaa@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'gbaum@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'rjirsara@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'annaxu@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'krmurtha@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'jbourque@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'vsydnor@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'ttapera@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa3']},
#                  {'access': None,
#                   'id': 'apines@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'blarsen@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'antoniak@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'eballer@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'sshanmugan@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'scott1@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'moberg@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'turetsky@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'kruparel@pennmedicine.upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa3']},
#                  {'access': None,
#                   'id': 'kalebfischer@flywheel.io',
#                   'role_ids': ['5ef07972374bc20010a37aa3']},
#                  {'access': None,
#                   'id': 'pinesa@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'linguiti@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'jrkantor@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'radreview@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'radreview@pennbrain.upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'larsenb@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'witschey@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'iyerk@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'Mrugank.Salunke@pennmedicine.upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'jjee@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'hyon1@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'nickwell@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'kahinim@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'kzoner@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'mruganks@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa5']},
#                  {'access': None,
#                   'id': 'irenak@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'hillmann@upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']},
#                  {'access': None,
#                   'id': 'tpremrud@seas.upenn.edu',
#                   'role_ids': ['5ef07972374bc20010a37aa4']}],
#  'providers': {'compute': None, 'storage': None},
#  'revision': 1217,
#  'tags': [],
#  'templates': []}

# %%
#iterate through subjects and sessions to access session containers 
subjects=EFProj.subjects()

sessions=[]
for s in subjects :
    tempsessions=s.sessions()
    sessions.extend(tempsessions)

# %%
print(len(sessions))
#print(sessions[28])
# Out:
# 170

# %%
#set directory to location of files for upload
root_dir = '/Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/'
bids_dir = 'BIDS_2022'
all_files=glob.glob(root_dir + bids_dir + '*/*/*')
print(len(all_files))
some_files=all_files[:4]
other_files=all_files[310:]
# Out:
# 314

# %%
#iterate through sessions, find matching tsv, and upload! 
for ses in sessions:
    scanid=ses.label
    for file in all_files:
        #print(file)
        f=file.split('/')
        g=(f[len(f)-1]).split('_')
        h=(g[1].split('-'))[1]
        if scanid == h:
            print("uploading {0} to {1}".format(file, scanid))
            ses.upload_file(file)
# Out:
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20303_ses-11206_task-fracback_acq-singleband_bold_events.tsv to 11206
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20303_ses-11206_task-fracback_acq-singleband_bold_events.json to 11206
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20303_ses-11604_task-fracback_acq-singleband_bold_events.json to 11604
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20303_ses-11604_task-fracback_acq-singleband_bold_events.tsv to 11604
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20403_ses-11211_task-fracback_acq-singleband_bold_events.json to 11211
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20403_ses-11211_task-fracback_acq-singleband_bold_events.tsv to 11211
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20302_ses-11208_task-fracback_acq-singleband_bold_events.json to 11208
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20302_ses-11208_task-fracback_acq-singleband_bold_events.tsv to 11208
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20302_ses-11603_task-fracback_acq-singleband_bold_events.tsv to 11603
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20302_ses-11603_task-fracback_acq-singleband_bold_events.json to 11603
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20212_ses-11209_task-fracback_acq-singleband_bold_events.json to 11209
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20212_ses-11209_task-fracback_acq-singleband_bold_events.tsv to 11209
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20402_ses-11210_task-fracback_acq-singleband_bold_events.tsv to 11210
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20402_ses-11210_task-fracback_acq-singleband_bold_events.json to 11210
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20448_ses-11217_task-fracback_acq-singleband_bold_events.tsv to 11217
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20448_ses-11217_task-fracback_acq-singleband_bold_events.json to 11217
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20427_ses-11233_task-fracback_acq-singleband_bold_events.json to 11233
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20427_ses-11233_task-fracback_acq-singleband_bold_events.tsv to 11233
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20427_ses-12098_task-fracback_acq-singleband_bold_events.tsv to 12098
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20427_ses-12098_task-fracback_acq-singleband_bold_events.json to 12098
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20463_ses-11238_task-fracback_acq-singleband_bold_events.json to 11238
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20463_ses-11238_task-fracback_acq-singleband_bold_events.tsv to 11238
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20463_ses-11679_task-fracback_acq-singleband_bold_events.json to 11679
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20463_ses-11679_task-fracback_acq-singleband_bold_events.tsv to 11679
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20310_ses-11242_task-fracback_acq-singleband_bold_events.tsv to 11242
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20310_ses-11242_task-fracback_acq-singleband_bold_events.json to 11242
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20310_ses-11635_task-fracback_acq-singleband_bold_events.tsv to 11635
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20310_ses-11635_task-fracback_acq-singleband_bold_events.json to 11635
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20612_ses-11264_task-fracback_acq-singleband_bold_events.json to 11264
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20612_ses-11264_task-fracback_acq-singleband_bold_events.tsv to 11264
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20494_ses-11276_task-fracback_acq-singleband_bold_events.tsv to 11276
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20494_ses-11276_task-fracback_acq-singleband_bold_events.json to 11276
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20494_ses-11738_task-fracback_acq-singleband_bold_events.tsv to 11738
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20494_ses-11738_task-fracback_acq-singleband_bold_events.json to 11738
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20258_ses-11584_task-fracback_acq-singleband_bold_events.tsv to 11584
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20258_ses-11584_task-fracback_acq-singleband_bold_events.json to 11584
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20572_ses-11289_task-fracback_acq-singleband_bold_events.tsv to 11289
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20572_ses-11289_task-fracback_acq-singleband_bold_events.json to 11289
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20572_ses-11771_task-fracback_acq-singleband_bold_events.tsv to 11771
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20572_ses-11771_task-fracback_acq-singleband_bold_events.json to 11771
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20287_ses-11290_task-fracback_acq-singleband_bold_events.json to 11290
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20287_ses-11290_task-fracback_acq-singleband_bold_events.tsv to 11290
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20533_ses-11302_task-fracback_acq-singleband_bold_events.json to 11302
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20533_ses-11302_task-fracback_acq-singleband_bold_events.tsv to 11302
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20724_ses-11319_task-fracback_acq-singleband_bold_events.tsv to 11319
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20724_ses-11319_task-fracback_acq-singleband_bold_events.json to 11319
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20721_ses-11321_task-fracback_acq-singleband_bold_events.json to 11321
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20721_ses-11321_task-fracback_acq-singleband_bold_events.tsv to 11321
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20721_ses-11692_task-fracback_acq-singleband_bold_events.tsv to 11692
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20721_ses-11692_task-fracback_acq-singleband_bold_events.json to 11692
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20691_ses-11320_task-fracback_acq-singleband_bold_events.json to 11320
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20691_ses-11320_task-fracback_acq-singleband_bold_events.tsv to 11320
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20691_ses-11694_task-fracback_acq-singleband_bold_events.json to 11694
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20691_ses-11694_task-fracback_acq-singleband_bold_events.tsv to 11694
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20724_ses-11319_task-fracback_acq-singleband_bold_events.tsv to 11319
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20724_ses-11319_task-fracback_acq-singleband_bold_events.json to 11319
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20238_ses-11316_task-fracback_acq-singleband_bold_events.tsv to 11316
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20238_ses-11316_task-fracback_acq-singleband_bold_events.json to 11316
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20238_ses-11612_task-fracback_acq-singleband_bold_events.tsv to 11612
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20238_ses-11612_task-fracback_acq-singleband_bold_events.json to 11612
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20626_ses-11324_task-fracback_acq-singleband_bold_events.json to 11324
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20626_ses-11324_task-fracback_acq-singleband_bold_events.tsv to 11324
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20626_ses-12182_task-fracback_acq-singleband_bold_events.json to 12182
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20626_ses-12182_task-fracback_acq-singleband_bold_events.tsv to 12182
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20794_ses-11332_task-fracback_acq-singleband_bold_events.json to 11332
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20794_ses-11332_task-fracback_acq-singleband_bold_events.tsv to 11332
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20812_ses-11334_task-fracback_acq-singleband_bold_events.tsv to 11334
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20812_ses-11334_task-fracback_acq-singleband_bold_events.json to 11334
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20836_ses-11359_task-fracback_acq-singleband_bold_events.json to 11359
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20836_ses-11359_task-fracback_acq-singleband_bold_events.tsv to 11359
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20836_ses-12168_task-fracback_acq-singleband_bold_events.json to 12168
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20836_ses-12168_task-fracback_acq-singleband_bold_events.tsv to 12168
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20902_ses-11399_task-fracback_acq-singleband_bold_events.json to 11399
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20902_ses-11399_task-fracback_acq-singleband_bold_events.tsv to 11399
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20902_ses-11835_task-fracback_acq-singleband_bold_events.json to 11835
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20902_ses-11835_task-fracback_acq-singleband_bold_events.tsv to 11835
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20214_ses-11126_task-fracback_acq-singleband_bold_events.json to 11126
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20214_ses-11126_task-fracback_acq-singleband_bold_events.tsv to 11126
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20214_ses-11659_task-fracback_acq-singleband_bold_events.json to 11659
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20214_ses-11659_task-fracback_acq-singleband_bold_events.tsv to 11659
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20352_ses-11147_task-fracback_acq-singleband_bold_events.tsv to 11147
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20352_ses-11147_task-fracback_acq-singleband_bold_events.json to 11147
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20352_ses-11660_task-fracback_acq-singleband_bold_events.tsv to 11660
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20352_ses-11660_task-fracback_acq-singleband_bold_events.json to 11660
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20328_ses-11207_task-fracback_acq-singleband_bold_events.json to 11207
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20328_ses-11207_task-fracback_acq-singleband_bold_events.tsv to 11207
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20328_ses-11678_task-fracback_acq-singleband_bold_events.tsv to 11678
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20328_ses-11678_task-fracback_acq-singleband_bold_events.json to 11678
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20253_ses-11142_task-fracback_acq-singleband_bold_events.tsv to 11142
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20253_ses-11142_task-fracback_acq-singleband_bold_events.json to 11142
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20253_ses-11608_task-fracback_acq-singleband_bold_events.json to 11608
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20253_ses-11608_task-fracback_acq-singleband_bold_events.tsv to 11608
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20336_ses-11146_task-fracback_acq-singleband_bold_events.tsv to 11146
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20336_ses-11146_task-fracback_acq-singleband_bold_events.json to 11146
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20350_ses-11184_task-fracback_acq-singleband_bold_events.tsv to 11184
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20350_ses-11184_task-fracback_acq-singleband_bold_events.json to 11184
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20934_ses-11387_task-fracback_acq-singleband_bold_events.tsv to 11387
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20934_ses-11387_task-fracback_acq-singleband_bold_events.json to 11387
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20188_ses-11140_task-fracback_acq-singleband_bold_events.tsv to 11140
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20188_ses-11140_task-fracback_acq-singleband_bold_events.json to 11140
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20188_ses-11594_task-fracback_acq-singleband_bold_events.tsv to 11594
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20188_ses-11594_task-fracback_acq-singleband_bold_events.json to 11594
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20866_ses-11381_task-fracback_acq-singleband_bold_events.json to 11381
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20866_ses-11381_task-fracback_acq-singleband_bold_events.tsv to 11381
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20866_ses-11882_task-fracback_acq-singleband_bold_events.json to 11882
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20866_ses-11882_task-fracback_acq-singleband_bold_events.tsv to 11882
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20855_ses-11392_task-fracback_acq-singleband_bold_events.tsv to 11392
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20855_ses-11392_task-fracback_acq-singleband_bold_events.json to 11392
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20865_ses-11376_task-fracback_acq-singleband_bold_events.tsv to 11376
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20865_ses-11376_task-fracback_acq-singleband_bold_events.json to 11376
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20865_ses-11881_task-fracback_acq-singleband_bold_events.json to 11881
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20865_ses-11881_task-fracback_acq-singleband_bold_events.tsv to 11881
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20149_ses-11003_task-fracback_acq-singleband_bold_events.json to 11003
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20149_ses-11003_task-fracback_acq-singleband_bold_events.tsv to 11003
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20149_ses-11831_task-fracback_acq-singleband_bold_events.tsv to 11831
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20149_ses-11831_task-fracback_acq-singleband_bold_events.json to 11831
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20259_ses-11127_task-fracback_acq-singleband_bold_events.json to 11127
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20259_ses-11127_task-fracback_acq-singleband_bold_events.tsv to 11127
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20259_ses-11823_task-fracback_acq-singleband_bold_events.json to 11823
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20259_ses-11823_task-fracback_acq-singleband_bold_events.tsv to 11823
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20333_ses-11160_task-fracback_acq-singleband_bold_events.tsv to 11160
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20333_ses-11160_task-fracback_acq-singleband_bold_events.json to 11160
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20712_ses-11370_task-fracback_acq-singleband_bold_events.json to 11370
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20712_ses-11370_task-fracback_acq-singleband_bold_events.tsv to 11370
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20712_ses-11747_task-fracback_acq-singleband_bold_events.tsv to 11747
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20712_ses-11747_task-fracback_acq-singleband_bold_events.json to 11747
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20823_ses-11375_task-fracback_acq-singleband_bold_events.tsv to 11375
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20823_ses-11375_task-fracback_acq-singleband_bold_events.json to 11375
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20916_ses-11397_task-fracback_acq-singleband_bold_events.json to 11397
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20916_ses-11397_task-fracback_acq-singleband_bold_events.tsv to 11397
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20916_ses-11946_task-fracback_acq-singleband_bold_events.tsv to 11946
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20916_ses-11946_task-fracback_acq-singleband_bold_events.json to 11946
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-19861_ses-11012_task-fracback_acq-singleband_bold_events.json to 11012
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-19861_ses-11012_task-fracback_acq-singleband_bold_events.tsv to 11012
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-19861_ses-12166_task-fracback_acq-singleband_bold_events.json to 12166
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-19861_ses-12166_task-fracback_acq-singleband_bold_events.tsv to 12166
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20305_ses-11159_task-fracback_acq-singleband_bold_events.tsv to 11159
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20305_ses-11159_task-fracback_acq-singleband_bold_events.json to 11159
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20919_ses-11386_task-fracback_acq-singleband_bold_events.json to 11386
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20919_ses-11386_task-fracback_acq-singleband_bold_events.tsv to 11386
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20918_ses-11385_task-fracback_acq-singleband_bold_events.tsv to 11385
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20918_ses-11385_task-fracback_acq-singleband_bold_events.json to 11385
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20347_ses-11132_task-fracback_acq-singleband_bold_events.json to 11132
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20347_ses-11132_task-fracback_acq-singleband_bold_events.tsv to 11132
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20252_ses-11143_task-fracback_acq-singleband_bold_events.tsv to 11143
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20252_ses-11143_task-fracback_acq-singleband_bold_events.json to 11143
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20252_ses-11607_task-fracback_acq-singleband_bold_events.tsv to 11607
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20252_ses-11607_task-fracback_acq-singleband_bold_events.json to 11607
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20399_ses-11180_task-fracback_acq-singleband_bold_events.tsv to 11180
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20399_ses-11180_task-fracback_acq-singleband_bold_events.json to 11180
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20399_ses-11631_task-fracback_acq-singleband_bold_events.json to 11631
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20399_ses-11631_task-fracback_acq-singleband_bold_events.tsv to 11631
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20923_ses-11388_task-fracback_acq-singleband_bold_events.json to 11388
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20923_ses-11388_task-fracback_acq-singleband_bold_events.tsv to 11388
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20923_ses-12032_task-fracback_acq-singleband_bold_events.json to 12032
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20923_ses-12032_task-fracback_acq-singleband_bold_events.tsv to 12032
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20139_ses-11138_task-fracback_acq-singleband_bold_events.tsv to 11138
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20139_ses-11138_task-fracback_acq-singleband_bold_events.json to 11138
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20139_ses-11657_task-fracback_acq-singleband_bold_events.json to 11657
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20139_ses-11657_task-fracback_acq-singleband_bold_events.tsv to 11657
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20818_ses-11365_task-fracback_acq-singleband_bold_events.tsv to 11365
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20818_ses-11365_task-fracback_acq-singleband_bold_events.json to 11365
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20818_ses-11719_task-fracback_acq-singleband_bold_events.json to 11719
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20818_ses-11719_task-fracback_acq-singleband_bold_events.tsv to 11719
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20849_ses-11366_task-fracback_acq-singleband_bold_events.tsv to 11366
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20849_ses-11366_task-fracback_acq-singleband_bold_events.json to 11366
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20141_ses-11000_task-fracback_acq-singleband_bold_events.tsv to 11000
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20141_ses-11000_task-fracback_acq-singleband_bold_events.json to 11000
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20410_ses-11205_task-fracback_acq-singleband_bold_events.tsv to 11205
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20410_ses-11205_task-fracback_acq-singleband_bold_events.json to 11205
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20842_ses-11404_task-fracback_acq-singleband_bold_events.json to 11404
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20842_ses-11404_task-fracback_acq-singleband_bold_events.tsv to 11404
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20964_ses-11416_task-fracback_acq-singleband_bold_events.json to 11416
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20964_ses-11416_task-fracback_acq-singleband_bold_events.tsv to 11416
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20936_ses-12004_task-fracback_acq-singleband_bold_events.tsv to 12004
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20936_ses-12004_task-fracback_acq-singleband_bold_events.json to 12004
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20966_ses-11433_task-fracback_acq-singleband_bold_events.tsv to 11433
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20966_ses-11433_task-fracback_acq-singleband_bold_events.json to 11433
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20966_ses-11897_task-fracback_acq-singleband_bold_events.tsv to 11897
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20966_ses-11897_task-fracback_acq-singleband_bold_events.json to 11897
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20976_ses-11419_task-fracback_acq-singleband_bold_events.json to 11419
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20976_ses-11419_task-fracback_acq-singleband_bold_events.tsv to 11419
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20976_ses-11873_task-fracback_acq-singleband_bold_events.tsv to 11873
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20976_ses-11873_task-fracback_acq-singleband_bold_events.json to 11873
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20983_ses-11436_task-fracback_acq-singleband_bold_events.json to 11436
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20983_ses-11436_task-fracback_acq-singleband_bold_events.tsv to 11436
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21035_ses-11438_task-fracback_acq-singleband_bold_events.tsv to 11438
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21035_ses-11438_task-fracback_acq-singleband_bold_events.json to 11438
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21035_ses-12060_task-fracback_acq-singleband_bold_events.tsv to 12060
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21035_ses-12060_task-fracback_acq-singleband_bold_events.json to 12060
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20968_ses-11443_task-fracback_acq-singleband_bold_events.tsv to 11443
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20968_ses-11443_task-fracback_acq-singleband_bold_events.json to 11443
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20968_ses-12063_task-fracback_acq-singleband_bold_events.json to 12063
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-20968_ses-12063_task-fracback_acq-singleband_bold_events.tsv to 12063
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20953_ses-11440_task-fracback_acq-singleband_bold_events.tsv to 11440
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-20953_ses-11440_task-fracback_acq-singleband_bold_events.json to 11440
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21038_ses-11448_task-fracback_acq-singleband_bold_events.json to 11448
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21038_ses-11448_task-fracback_acq-singleband_bold_events.tsv to 11448
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21038_ses-11931_task-fracback_acq-singleband_bold_events.json to 11931
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21038_ses-11931_task-fracback_acq-singleband_bold_events.tsv to 11931
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21050_ses-11451_task-fracback_acq-singleband_bold_events.json to 11451
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21050_ses-11451_task-fracback_acq-singleband_bold_events.tsv to 11451
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21023_ses-11452_task-fracback_acq-singleband_bold_events.tsv to 11452
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21023_ses-11452_task-fracback_acq-singleband_bold_events.json to 11452
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21023_ses-11891_task-fracback_acq-singleband_bold_events.tsv to 11891
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21023_ses-11891_task-fracback_acq-singleband_bold_events.json to 11891
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21088_ses-11455_task-fracback_acq-singleband_bold_events.tsv to 11455
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21088_ses-11455_task-fracback_acq-singleband_bold_events.json to 11455
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21095_ses-11460_task-fracback_acq-singleband_bold_events.json to 11460
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21095_ses-11460_task-fracback_acq-singleband_bold_events.tsv to 11460
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21131_ses-11465_task-fracback_acq-singleband_bold_events.tsv to 11465
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21131_ses-11465_task-fracback_acq-singleband_bold_events.json to 11465
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21104_ses-11475_task-fracback_acq-singleband_bold_events.json to 11475
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21104_ses-11475_task-fracback_acq-singleband_bold_events.tsv to 11475
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21104_ses-12044_task-fracback_acq-singleband_bold_events.json to 12044
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21104_ses-12044_task-fracback_acq-singleband_bold_events.tsv to 12044
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21112_ses-11468_task-fracback_acq-singleband_bold_events.json to 11468
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21112_ses-11468_task-fracback_acq-singleband_bold_events.tsv to 11468
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21146_ses-11488_task-fracback_acq-singleband_bold_events.tsv to 11488
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21146_ses-11488_task-fracback_acq-singleband_bold_events.json to 11488
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21124_ses-11473_task-fracback_acq-singleband_bold_events.json to 11473
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21124_ses-11473_task-fracback_acq-singleband_bold_events.tsv to 11473
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21154_ses-11492_task-fracback_acq-singleband_bold_events.json to 11492
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21154_ses-11492_task-fracback_acq-singleband_bold_events.tsv to 11492
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21154_ses-12187_task-fracback_acq-singleband_bold_events.json to 12187
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21154_ses-12187_task-fracback_acq-singleband_bold_events.tsv to 12187
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21161_ses-11541_task-fracback_acq-singleband_bold_events.json to 11541
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21161_ses-11541_task-fracback_acq-singleband_bold_events.tsv to 11541
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21161_ses-12143_task-fracback_acq-singleband_bold_events.json to 12143
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T2/sub-21161_ses-12143_task-fracback_acq-singleband_bold_events.tsv to 12143
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-138950_ses-11533_task-fracback_acq-singleband_bold_events.tsv to 11533
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-138950_ses-11533_task-fracback_acq-singleband_bold_events.json to 11533
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21141_ses-11574_task-fracback_acq-singleband_bold_events.json to 11574
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21141_ses-11574_task-fracback_acq-singleband_bold_events.tsv to 11574
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21193_ses-11576_task-fracback_acq-singleband_bold_events.json to 11576
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21193_ses-11576_task-fracback_acq-singleband_bold_events.tsv to 11576
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21118_ses-11577_task-fracback_acq-singleband_bold_events.tsv to 11577
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21118_ses-11577_task-fracback_acq-singleband_bold_events.json to 11577
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21224_ses-11625_task-fracback_acq-singleband_bold_events.tsv to 11625
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21224_ses-11625_task-fracback_acq-singleband_bold_events.json to 11625
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21139_ses-11640_task-fracback_acq-singleband_bold_events.json to 11640
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21139_ses-11640_task-fracback_acq-singleband_bold_events.tsv to 11640
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21325_ses-11651_task-fracback_acq-singleband_bold_events.tsv to 11651
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21325_ses-11651_task-fracback_acq-singleband_bold_events.json to 11651
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21432_ses-11664_task-fracback_acq-singleband_bold_events.tsv to 11664
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21432_ses-11664_task-fracback_acq-singleband_bold_events.json to 11664
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21345_ses-11702_task-fracback_acq-singleband_bold_events.json to 11702
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21345_ses-11702_task-fracback_acq-singleband_bold_events.tsv to 11702
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21150_ses-11720_task-fracback_acq-singleband_bold_events.json to 11720
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21150_ses-11720_task-fracback_acq-singleband_bold_events.tsv to 11720
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21516_ses-11723_task-fracback_acq-singleband_bold_events.json to 11723
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21516_ses-11723_task-fracback_acq-singleband_bold_events.tsv to 11723
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21560_ses-11750_task-fracback_acq-singleband_bold_events.json to 11750
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21560_ses-11750_task-fracback_acq-singleband_bold_events.tsv to 11750
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21580_ses-11751_task-fracback_acq-singleband_bold_events.tsv to 11751
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21580_ses-11751_task-fracback_acq-singleband_bold_events.json to 11751
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21568_ses-11755_task-fracback_acq-singleband_bold_events.tsv to 11755
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21568_ses-11755_task-fracback_acq-singleband_bold_events.json to 11755
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21539_ses-11780_task-fracback_acq-singleband_bold_events.json to 11780
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21539_ses-11780_task-fracback_acq-singleband_bold_events.tsv to 11780
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21567_ses-11779_task-fracback_acq-singleband_bold_events.tsv to 11779
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21567_ses-11779_task-fracback_acq-singleband_bold_events.json to 11779
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21623_ses-11793_task-fracback_acq-singleband_bold_events.tsv to 11793
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21623_ses-11793_task-fracback_acq-singleband_bold_events.json to 11793
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21493_ses-11794_task-fracback_acq-singleband_bold_events.tsv to 11794
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21493_ses-11794_task-fracback_acq-singleband_bold_events.json to 11794
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21197_ses-11798_task-fracback_acq-singleband_bold_events.json to 11798
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21197_ses-11798_task-fracback_acq-singleband_bold_events.tsv to 11798
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21553_ses-11824_task-fracback_acq-singleband_bold_events.json to 11824
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21553_ses-11824_task-fracback_acq-singleband_bold_events.tsv to 11824
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21554_ses-11825_task-fracback_acq-singleband_bold_events.tsv to 11825
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21554_ses-11825_task-fracback_acq-singleband_bold_events.json to 11825
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21514_ses-11829_task-fracback_acq-singleband_bold_events.json to 11829
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21514_ses-11829_task-fracback_acq-singleband_bold_events.tsv to 11829
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21712_ses-11848_task-fracback_acq-singleband_bold_events.tsv to 11848
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21712_ses-11848_task-fracback_acq-singleband_bold_events.json to 11848
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21827_ses-11853_task-fracback_acq-singleband_bold_events.tsv to 11853
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21827_ses-11853_task-fracback_acq-singleband_bold_events.json to 11853
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21797_ses-11862_task-fracback_acq-singleband_bold_events.json to 11862
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21797_ses-11862_task-fracback_acq-singleband_bold_events.tsv to 11862
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21738_ses-11875_task-fracback_acq-singleband_bold_events.tsv to 11875
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21738_ses-11875_task-fracback_acq-singleband_bold_events.json to 11875
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21855_ses-11885_task-fracback_acq-singleband_bold_events.json to 11885
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21855_ses-11885_task-fracback_acq-singleband_bold_events.tsv to 11885
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21856_ses-11886_task-fracback_acq-singleband_bold_events.tsv to 11886
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-21856_ses-11886_task-fracback_acq-singleband_bold_events.json to 11886
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22045_ses-11960_task-fracback_acq-singleband_bold_events.tsv to 11960
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22045_ses-11960_task-fracback_acq-singleband_bold_events.json to 11960
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22064_ses-11981_task-fracback_acq-singleband_bold_events.json to 11981
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22064_ses-11981_task-fracback_acq-singleband_bold_events.tsv to 11981
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22510_ses-12046_task-fracback_acq-singleband_bold_events.tsv to 12046
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22510_ses-12046_task-fracback_acq-singleband_bold_events.json to 12046
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22520_ses-12057_task-fracback_acq-singleband_bold_events.tsv to 12057
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22520_ses-12057_task-fracback_acq-singleband_bold_events.json to 12057
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22618_ses-12081_task-fracback_acq-singleband_bold_events.tsv to 12081
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22618_ses-12081_task-fracback_acq-singleband_bold_events.json to 12081
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22617_ses-12080_task-fracback_acq-singleband_bold_events.json to 12080
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22617_ses-12080_task-fracback_acq-singleband_bold_events.tsv to 12080
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22473_ses-12097_task-fracback_acq-singleband_bold_events.json to 12097
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22473_ses-12097_task-fracback_acq-singleband_bold_events.tsv to 12097
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22654_ses-12107_task-fracback_acq-singleband_bold_events.tsv to 12107
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22654_ses-12107_task-fracback_acq-singleband_bold_events.json to 12107
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22653_ses-12106_task-fracback_acq-singleband_bold_events.json to 12106
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22653_ses-12106_task-fracback_acq-singleband_bold_events.tsv to 12106
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22870_ses-12157_task-fracback_acq-singleband_bold_events.json to 12157
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22870_ses-12157_task-fracback_acq-singleband_bold_events.tsv to 12157
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22745_ses-12185_task-fracback_acq-singleband_bold_events.tsv to 12185
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22745_ses-12185_task-fracback_acq-singleband_bold_events.json to 12185
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22744_ses-12184_task-fracback_acq-singleband_bold_events.tsv to 12184
# uploading /Users/krmurtha/Box Sync/EXECUTIVE_FUNCTION/SCANNER_TASK/BIDS_2022/T1/sub-22744_ses-12184_task-fracback_acq-singleband_bold_events.json to 12184
